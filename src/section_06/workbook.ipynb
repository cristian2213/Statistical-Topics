# %%
from stats import Statistics

# ******************************
# DISCRETE PROBABILITY
# ******************************
# 2
data = [(0, 1 / 5), (5, 1 / 5), (10, 2 / 5), (15, 1 / 5)]
res = Statistics.get_discrete_variance(data)
mean = res[1]
variance = res[0]
std = Statistics.get_discrete_std(variance)
print("#2", "mean ->", mean, "variance ->", variance, "std ->", std)

# 3
household_3 = 1 - (0.281 + 0.340 + 0.129 + 0.060 + 0.023 + 0.013)
p_at_least_4 = 1 - (0.281 + 0.340 + household_3)  # P(X>=4) = 1 - P(X<4)
p_at_least_2 = 1 - 0.28  # P(X>=2) = 1 - P(X=1)
p_at_least_4_given_at_least_2 = p_at_least_4 / p_at_least_2
print(
    "#3",
    "p_at_least_2 ->",
    p_at_least_2,
    "p_at_least_4 ->",
    p_at_least_4,
    "p_at_least_4_given_at_least_2 ->",
    p_at_least_4_given_at_least_2,
)
# 4
# total cards = 52
# red cards = 26
# black cards = 26
deck = 52
p_both_red = 0
p_both_black = 0
p_one_red = 0
print()
# Out:
# #2 mean -> 8.0 variance -> 26.0 std -> 5.0990195135927845
# #3 p_at_least_2 -> 0.72 p_at_least_4 -> 0.2250000000000001 p_at_least_4_given_at_least_2 -> 0.3125000000000001
# r_1 -> 0.5 r_2 -> 0.49019607843137253
